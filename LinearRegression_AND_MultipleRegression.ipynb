# %% [markdown]
# <a href="https://colab.research.google.com/github/SandeshSarje/Data_Science/blob/main/LinearRegression_AND_MultipleRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Linear Regression**

# %%
# Imports Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
# Define X and Y
X = df[['total_bill']]
Y = df['tip']

# %%
# Train Test Split
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
# Train Model
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Prediction
Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([3.04525623, 1.86330727, 3.55119456, 3.69452593, 2.31576375,
#        2.83881627, 3.96728338, 2.26014262, 2.50615915, 2.57033737,
#        2.88160176, 2.07723468, 2.06439904, 2.47407003, 2.00236009,
#        2.91903905, 2.92652651, 3.23351235, 2.68478854, 5.33107064,
#        3.13831465, 3.13403611, 2.4558862 , 1.94673896, 3.16077703,
#        2.17564129, 2.02375283, 3.62927807, 2.68906708, 6.07767732,
#        4.99734388, 1.75313465, 2.83025918, 3.09552917, 2.74040966,
#        3.50092162, 2.21200895, 5.53644096, 2.33287794, 3.35010279,
#        2.04942412, 2.47834858, 3.48701634, 2.03017065, 2.03124029,
#        1.25361414, 2.05798121, 2.92438724, 1.73388118])

# %%
# Best Fit line Parameters

m = model.coef_[0]
c = model.intercept_

print("Slope m is:", m)
print("Intercept c is:",c)
# Out:
# Slope m is: 0.10696370685268658
# Intercept c is: 0.925235558557056

# %%
# plot

plt.scatter(X_test, Y_test)
plt.plot(X_test, Y_pred)

plt.xlabel("Total Bill")
plt.ylabel("Tip")

plt.title("Simple Linear Regression")
plt.show()

# %% [markdown]
# **Multiple Linear Regression**

# %%
# Loading Dataset
df = sns.load_dataset("mpg")
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
df.dropna()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mean_value = df['horsepower'].mean()
df['horsepower'].fillna(mean_value, inplace=True)
# Out:
# /tmp/ipykernel_4515/374359604.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['horsepower'].fillna(mean_value, inplace=True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
# Features and Target
X = df[['horsepower', 'weight', 'displacement']]
Y = df['mpg']

# %%
# Train Test Split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
# Train model
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Predictions
Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([32.72009504, 27.02115149, 25.17173158, 15.49717579, 13.90597931,
#        29.69503345, 25.06021008,  7.66610889, 16.90002676, 23.99510676,
#        13.80876038, 31.27430806, 31.2132406 , 15.87917637, 27.44034744,
#         8.33321468, 27.13107921, 22.12071573, 12.11943573, 31.20930587,
#        27.73763991, 24.59982502, 23.63628884, 30.01112742, 18.69544758,
#        30.91002371, 28.72568971, 25.78467641, 20.01813357,  8.94093365,
#        25.69131357, 30.80160652, 16.38149458, 28.33121507, 31.10601317,
#         9.89797874, 26.45876272, 18.56331358, 12.50765513, 29.23963821,
#        24.77101785, 32.1901477 , 24.10103077,  9.02237382, 26.97084301,
#        29.16848941, 29.24019353, 25.39006942, 27.89178406, 29.74811607,
#        28.2729041 , 31.34174598, 29.19935651, 10.65506417, 24.82815058,
#        11.00326197, 15.12266323, 26.01520545, 28.35653472, 22.04995691,
#        15.54408955, 32.72009504, 26.61494882, 24.81885894, 24.21943799,
# ...

# %%
# Plot

plt.scatter(Y_test, Y_pred)
plt.xlabel("Actual MPG")
plt.ylabel("Predicted MPG")
plt.title("Multiple Regression")

# Best fit line
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()])

plt.show()
